# %%
import os, sys
sys.path.append('lib')
import numpy as np
from kmeans import kMeans_init_centroids, run_kMeans, find_closest_centroids
from InputDataProcessor import InputDataProcessor

# %%
idp=InputDataProcessor(bucket_name='aiml_harveen', use_case='c3w1/kmeans', file_name='ex7_X.npy')

# %%
X=idp.loadNumpy()
# Out:
# c3w1/kmeans/orig_data/ex7_X.npy

# %%
X=X[:5]

# %%
X
# Out:
# array([[1.84207953, 4.6075716 ],
#        [5.65858312, 4.79996405],
#        [6.35257892, 3.2908545 ],
#        [2.90401653, 4.61220411],
#        [3.23197916, 4.93989405]])

# %%
K = 3
max_iters = 10

# %%
initial_centroids = kMeans_init_centroids(X, K)

# %%
initial_centroids
# Out:
# array([[6.35257892, 3.2908545 ],
#        [1.84207953, 4.6075716 ],
#        [3.23197916, 4.93989405]])

# %%
find_closest_centroids(X,initial_centroids)
# Out:
# array([1, 0, 0, 2, 2])

# %%
centroids, idx = run_kMeans(X, initial_centroids, max_iters)
# Out:
# K-Means iteration 0/9
# K-Means iteration 1/9
# K-Means iteration 2/9
# K-Means iteration 3/9
# K-Means iteration 4/9
# K-Means iteration 5/9
# K-Means iteration 6/9
# K-Means iteration 7/9
# K-Means iteration 8/9
# K-Means iteration 9/9

# %%
centroids
# Out:
# array([[6.00558102, 4.04540928],
#        [1.84207953, 4.6075716 ],
#        [3.06799784, 4.77604908]])

# %%
K = 3
max_iters = 20

# %%
initial_centroids = kMeans_init_centroids(X, K)

# %%
centroids, idx = run_kMeans(X, initial_centroids, max_iters)
# Out:
# K-Means iteration 0/19
# K-Means iteration 1/19
# K-Means iteration 2/19
# K-Means iteration 3/19
# K-Means iteration 4/19
# K-Means iteration 5/19
# K-Means iteration 6/19
# K-Means iteration 7/19
# K-Means iteration 8/19
# K-Means iteration 9/19
# K-Means iteration 10/19
# K-Means iteration 11/19
# K-Means iteration 12/19
# K-Means iteration 13/19
# K-Means iteration 14/19
# K-Means iteration 15/19
# K-Means iteration 16/19
# K-Means iteration 17/19
# K-Means iteration 18/19
# K-Means iteration 19/19

# %%
centroids
# Out:
# array([[1.84207953, 4.6075716 ],
#        [6.00558102, 4.04540928],
#        [3.06799784, 4.77604908]])

# %%
K = 3
max_iters = 50

# %%
initial_centroids = kMeans_init_centroids(X, K)

# %%
centroids, idx = run_kMeans(X, initial_centroids, max_iters)
# Out:
# K-Means iteration 0/49
# K-Means iteration 1/49
# K-Means iteration 2/49
# K-Means iteration 3/49
# K-Means iteration 4/49
# K-Means iteration 5/49
# K-Means iteration 6/49
# K-Means iteration 7/49
# K-Means iteration 8/49
# K-Means iteration 9/49
# K-Means iteration 10/49
# K-Means iteration 11/49
# K-Means iteration 12/49
# K-Means iteration 13/49
# K-Means iteration 14/49
# K-Means iteration 15/49
# K-Means iteration 16/49
# K-Means iteration 17/49
# K-Means iteration 18/49
# K-Means iteration 19/49
# K-Means iteration 20/49
# K-Means iteration 21/49
# K-Means iteration 22/49
# K-Means iteration 23/49
# K-Means iteration 24/49
# K-Means iteration 25/49
# K-Means iteration 26/49
# K-Means iteration 27/49
# K-Means iteration 28/49
# K-Means iteration 29/49
# K-Means iteration 30/49
# K-Means iteration 31/49
# K-Means iteration 32/49
# K-Means iteration 33/49
# K-Means iteration 34/49
# K-Means iteration 35/49
# K-Means iteration 36/49
# K-Means iteration 37/49
# K-Means iteration 38/49
# K-Means iteration 39/49
# K-Means iteration 40/49
# K-Means iteration 41/49
# K-Means iteration 42/49
# K-Means iteration 43/49
# K-Means iteration 44/49
# K-Means iteration 45/49
# K-Means iteration 46/49
# K-Means iteration 47/49
# K-Means iteration 48/49
# K-Means iteration 49/49

# %%
centroids
# Out:
# array([[5.65858312, 4.79996405],
#        [2.6593584 , 4.71988992],
#        [6.35257892, 3.2908545 ]])

# %%
K = 3
max_iters = 100

# %%
initial_centroids = kMeans_init_centroids(X, K)

# %%
centroids, idx = run_kMeans(X, initial_centroids, max_iters)
# Out:
# K-Means iteration 0/99
# K-Means iteration 1/99
# K-Means iteration 2/99
# K-Means iteration 3/99
# K-Means iteration 4/99
# K-Means iteration 5/99
# K-Means iteration 6/99
# K-Means iteration 7/99
# K-Means iteration 8/99
# K-Means iteration 9/99
# K-Means iteration 10/99
# K-Means iteration 11/99
# K-Means iteration 12/99
# K-Means iteration 13/99
# K-Means iteration 14/99
# K-Means iteration 15/99
# K-Means iteration 16/99
# K-Means iteration 17/99
# K-Means iteration 18/99
# K-Means iteration 19/99
# K-Means iteration 20/99
# K-Means iteration 21/99
# K-Means iteration 22/99
# K-Means iteration 23/99
# K-Means iteration 24/99
# K-Means iteration 25/99
# K-Means iteration 26/99
# K-Means iteration 27/99
# K-Means iteration 28/99
# K-Means iteration 29/99
# K-Means iteration 30/99
# K-Means iteration 31/99
# K-Means iteration 32/99
# K-Means iteration 33/99
# K-Means iteration 34/99
# K-Means iteration 35/99
# K-Means iteration 36/99
# K-Means iteration 37/99
# K-Means iteration 38/99
# K-Means iteration 39/99
# K-Means iteration 40/99
# K-Means iteration 41/99
# K-Means iteration 42/99
# K-Means iteration 43/99
# K-Means iteration 44/99
# K-Means iteration 45/99
# K-Means iteration 46/99
# K-Means iteration 47/99
# K-Means iteration 48/99
# K-Means iteration 49/99
# K-Means iteration 50/99
# K-Means iteration 51/99
# K-Means iteration 52/99
# K-Means iteration 53/99
# K-Means iteration 54/99
# K-Means iteration 55/99
# K-Means iteration 56/99
# K-Means iteration 57/99
# K-Means iteration 58/99
# K-Means iteration 59/99
# K-Means iteration 60/99
# K-Means iteration 61/99
# K-Means iteration 62/99
# K-Means iteration 63/99
# K-Means iteration 64/99
# K-Means iteration 65/99
# K-Means iteration 66/99
# K-Means iteration 67/99
# K-Means iteration 68/99
# K-Means iteration 69/99
# K-Means iteration 70/99
# K-Means iteration 71/99
# K-Means iteration 72/99
# K-Means iteration 73/99
# K-Means iteration 74/99
# K-Means iteration 75/99
# K-Means iteration 76/99
# K-Means iteration 77/99
# K-Means iteration 78/99
# K-Means iteration 79/99
# K-Means iteration 80/99
# K-Means iteration 81/99
# K-Means iteration 82/99
# K-Means iteration 83/99
# K-Means iteration 84/99
# K-Means iteration 85/99
# K-Means iteration 86/99
# K-Means iteration 87/99
# K-Means iteration 88/99
# K-Means iteration 89/99
# K-Means iteration 90/99
# K-Means iteration 91/99
# K-Means iteration 92/99
# K-Means iteration 93/99
# K-Means iteration 94/99
# K-Means iteration 95/99
# K-Means iteration 96/99
# K-Means iteration 97/99
# K-Means iteration 98/99
# K-Means iteration 99/99

# %%
centroids
# Out:
# array([[1.95399466, 5.02557006],
#        [3.04367119, 1.01541041],
#        [6.03366736, 3.00052511]])

# %%
K = 3
max_iters = 500
initial_centroids = kMeans_init_centroids(X, K)
centroids, idx = run_kMeans(X, initial_centroids, max_iters)
centroids
# Out:
# K-Means iteration 0/499
# K-Means iteration 1/499
# K-Means iteration 2/499
# K-Means iteration 3/499
# K-Means iteration 4/499
# K-Means iteration 5/499
# K-Means iteration 6/499
# K-Means iteration 7/499
# K-Means iteration 8/499
# K-Means iteration 9/499
# K-Means iteration 10/499
# K-Means iteration 11/499
# K-Means iteration 12/499
# K-Means iteration 13/499
# K-Means iteration 14/499
# K-Means iteration 15/499
# K-Means iteration 16/499
# K-Means iteration 17/499
# K-Means iteration 18/499
# K-Means iteration 19/499
# K-Means iteration 20/499
# K-Means iteration 21/499
# K-Means iteration 22/499
# K-Means iteration 23/499
# K-Means iteration 24/499
# K-Means iteration 25/499
# K-Means iteration 26/499
# K-Means iteration 27/499
# K-Means iteration 28/499
# K-Means iteration 29/499
# K-Means iteration 30/499
# K-Means iteration 31/499
# K-Means iteration 32/499
# K-Means iteration 33/499
# K-Means iteration 34/499
# K-Means iteration 35/499
# K-Means iteration 36/499
# K-Means iteration 37/499
# K-Means iteration 38/499
# K-Means iteration 39/499
# K-Means iteration 40/499
# K-Means iteration 41/499
# K-Means iteration 42/499
# K-Means iteration 43/499
# K-Means iteration 44/499
# K-Means iteration 45/499
# K-Means iteration 46/499
# K-Means iteration 47/499
# K-Means iteration 48/499
# K-Means iteration 49/499
# K-Means iteration 50/499
# K-Means iteration 51/499
# K-Means iteration 52/499
# K-Means iteration 53/499
# K-Means iteration 54/499
# K-Means iteration 55/499
# K-Means iteration 56/499
# K-Means iteration 57/499
# K-Means iteration 58/499
# K-Means iteration 59/499
# K-Means iteration 60/499
# K-Means iteration 61/499
# K-Means iteration 62/499
# K-Means iteration 63/499
# K-Means iteration 64/499
# K-Means iteration 65/499
# K-Means iteration 66/499
# K-Means iteration 67/499
# K-Means iteration 68/499
# K-Means iteration 69/499
# K-Means iteration 70/499
# K-Means iteration 71/499
# K-Means iteration 72/499
# K-Means iteration 73/499
# K-Means iteration 74/499
# K-Means iteration 75/499
# K-Means iteration 76/499
# K-Means iteration 77/499
# K-Means iteration 78/499
# K-Means iteration 79/499
# K-Means iteration 80/499
# K-Means iteration 81/499
# K-Means iteration 82/499
# K-Means iteration 83/499
# K-Means iteration 84/499
# K-Means iteration 85/499
# K-Means iteration 86/499
# K-Means iteration 87/499
# K-Means iteration 88/499
# K-Means iteration 89/499
# K-Means iteration 90/499
# K-Means iteration 91/499
# K-Means iteration 92/499
# K-Means iteration 93/499
# K-Means iteration 94/499
# K-Means iteration 95/499
# K-Means iteration 96/499
# K-Means iteration 97/499
# K-Means iteration 98/499
# K-Means iteration 99/499
# K-Means iteration 100/499
# K-Means iteration 101/499
# K-Means iteration 102/499
# K-Means iteration 103/499
# K-Means iteration 104/499
# K-Means iteration 105/499
# K-Means iteration 106/499
# K-Means iteration 107/499
# K-Means iteration 108/499
# K-Means iteration 109/499
# K-Means iteration 110/499
# K-Means iteration 111/499
# K-Means iteration 112/499
# K-Means iteration 113/499
# K-Means iteration 114/499
# K-Means iteration 115/499
# K-Means iteration 116/499
# K-Means iteration 117/499
# K-Means iteration 118/499
# K-Means iteration 119/499
# K-Means iteration 120/499
# K-Means iteration 121/499
# K-Means iteration 122/499
# K-Means iteration 123/499
# K-Means iteration 124/499
# K-Means iteration 125/499
# K-Means iteration 126/499
# K-Means iteration 127/499
# K-Means iteration 128/499
# K-Means iteration 129/499
# K-Means iteration 130/499
# K-Means iteration 131/499
# K-Means iteration 132/499
# K-Means iteration 133/499
# K-Means iteration 134/499
# K-Means iteration 135/499
# K-Means iteration 136/499
# K-Means iteration 137/499
# K-Means iteration 138/499
# K-Means iteration 139/499
# K-Means iteration 140/499
# K-Means iteration 141/499
# K-Means iteration 142/499
# K-Means iteration 143/499
# K-Means iteration 144/499
# K-Means iteration 145/499
# K-Means iteration 146/499
# K-Means iteration 147/499
# K-Means iteration 148/499
# K-Means iteration 149/499
# K-Means iteration 150/499
# K-Means iteration 151/499
# K-Means iteration 152/499
# K-Means iteration 153/499
# K-Means iteration 154/499
# K-Means iteration 155/499
# K-Means iteration 156/499
# K-Means iteration 157/499
# K-Means iteration 158/499
# K-Means iteration 159/499
# K-Means iteration 160/499
# K-Means iteration 161/499
# K-Means iteration 162/499
# K-Means iteration 163/499
# K-Means iteration 164/499
# K-Means iteration 165/499
# K-Means iteration 166/499
# K-Means iteration 167/499
# K-Means iteration 168/499
# K-Means iteration 169/499
# K-Means iteration 170/499
# K-Means iteration 171/499
# K-Means iteration 172/499
# K-Means iteration 173/499
# K-Means iteration 174/499
# K-Means iteration 175/499
# K-Means iteration 176/499
# K-Means iteration 177/499
# K-Means iteration 178/499
# K-Means iteration 179/499
# K-Means iteration 180/499
# K-Means iteration 181/499
# K-Means iteration 182/499
# K-Means iteration 183/499
# K-Means iteration 184/499
# K-Means iteration 185/499
# K-Means iteration 186/499
# K-Means iteration 187/499
# K-Means iteration 188/499
# K-Means iteration 189/499
# K-Means iteration 190/499
# K-Means iteration 191/499
# K-Means iteration 192/499
# K-Means iteration 193/499
# K-Means iteration 194/499
# K-Means iteration 195/499
# K-Means iteration 196/499
# K-Means iteration 197/499
# K-Means iteration 198/499
# K-Means iteration 199/499
# K-Means iteration 200/499
# K-Means iteration 201/499
# K-Means iteration 202/499
# K-Means iteration 203/499
# K-Means iteration 204/499
# K-Means iteration 205/499
# K-Means iteration 206/499
# K-Means iteration 207/499
# K-Means iteration 208/499
# K-Means iteration 209/499
# K-Means iteration 210/499
# K-Means iteration 211/499
# K-Means iteration 212/499
# K-Means iteration 213/499
# K-Means iteration 214/499
# K-Means iteration 215/499
# K-Means iteration 216/499
# K-Means iteration 217/499
# K-Means iteration 218/499
# K-Means iteration 219/499
# K-Means iteration 220/499
# K-Means iteration 221/499
# K-Means iteration 222/499
# K-Means iteration 223/499
# K-Means iteration 224/499
# K-Means iteration 225/499
# K-Means iteration 226/499
# K-Means iteration 227/499
# K-Means iteration 228/499
# K-Means iteration 229/499
# K-Means iteration 230/499
# K-Means iteration 231/499
# K-Means iteration 232/499
# K-Means iteration 233/499
# K-Means iteration 234/499
# K-Means iteration 235/499
# K-Means iteration 236/499
# K-Means iteration 237/499
# K-Means iteration 238/499
# K-Means iteration 239/499
# K-Means iteration 240/499
# K-Means iteration 241/499
# K-Means iteration 242/499
# K-Means iteration 243/499
# K-Means iteration 244/499
# K-Means iteration 245/499
# K-Means iteration 246/499
# K-Means iteration 247/499
# K-Means iteration 248/499
# K-Means iteration 249/499
# K-Means iteration 250/499
# K-Means iteration 251/499
# K-Means iteration 252/499
# K-Means iteration 253/499
# K-Means iteration 254/499
# K-Means iteration 255/499
# K-Means iteration 256/499
# K-Means iteration 257/499
# K-Means iteration 258/499
# K-Means iteration 259/499
# K-Means iteration 260/499
# K-Means iteration 261/499
# K-Means iteration 262/499
# K-Means iteration 263/499
# K-Means iteration 264/499
# K-Means iteration 265/499
# K-Means iteration 266/499
# K-Means iteration 267/499
# K-Means iteration 268/499
# K-Means iteration 269/499
# K-Means iteration 270/499
# K-Means iteration 271/499
# K-Means iteration 272/499
# K-Means iteration 273/499
# K-Means iteration 274/499
# K-Means iteration 275/499
# K-Means iteration 276/499
# K-Means iteration 277/499
# K-Means iteration 278/499
# K-Means iteration 279/499
# K-Means iteration 280/499
# K-Means iteration 281/499
# K-Means iteration 282/499
# K-Means iteration 283/499
# K-Means iteration 284/499
# K-Means iteration 285/499
# K-Means iteration 286/499
# K-Means iteration 287/499
# K-Means iteration 288/499
# K-Means iteration 289/499
# K-Means iteration 290/499
# K-Means iteration 291/499
# K-Means iteration 292/499
# K-Means iteration 293/499
# K-Means iteration 294/499
# K-Means iteration 295/499
# K-Means iteration 296/499
# K-Means iteration 297/499
# K-Means iteration 298/499
# K-Means iteration 299/499
# K-Means iteration 300/499
# K-Means iteration 301/499
# K-Means iteration 302/499
# K-Means iteration 303/499
# K-Means iteration 304/499
# K-Means iteration 305/499
# K-Means iteration 306/499
# K-Means iteration 307/499
# K-Means iteration 308/499
# K-Means iteration 309/499
# K-Means iteration 310/499
# K-Means iteration 311/499
# K-Means iteration 312/499
# K-Means iteration 313/499
# K-Means iteration 314/499
# K-Means iteration 315/499
# K-Means iteration 316/499
# K-Means iteration 317/499
# K-Means iteration 318/499
# K-Means iteration 319/499
# K-Means iteration 320/499
# K-Means iteration 321/499
# K-Means iteration 322/499
# K-Means iteration 323/499
# K-Means iteration 324/499
# K-Means iteration 325/499
# K-Means iteration 326/499
# K-Means iteration 327/499
# K-Means iteration 328/499
# K-Means iteration 329/499
# K-Means iteration 330/499
# K-Means iteration 331/499
# K-Means iteration 332/499
# K-Means iteration 333/499
# K-Means iteration 334/499
# K-Means iteration 335/499
# K-Means iteration 336/499
# K-Means iteration 337/499
# K-Means iteration 338/499
# K-Means iteration 339/499
# K-Means iteration 340/499
# K-Means iteration 341/499
# K-Means iteration 342/499
# K-Means iteration 343/499
# K-Means iteration 344/499
# K-Means iteration 345/499
# K-Means iteration 346/499
# K-Means iteration 347/499
# K-Means iteration 348/499
# K-Means iteration 349/499
# K-Means iteration 350/499
# K-Means iteration 351/499
# K-Means iteration 352/499
# K-Means iteration 353/499
# K-Means iteration 354/499
# K-Means iteration 355/499
# K-Means iteration 356/499
# K-Means iteration 357/499
# K-Means iteration 358/499
# K-Means iteration 359/499
# K-Means iteration 360/499
# K-Means iteration 361/499
# K-Means iteration 362/499
# K-Means iteration 363/499
# K-Means iteration 364/499
# K-Means iteration 365/499
# K-Means iteration 366/499
# K-Means iteration 367/499
# K-Means iteration 368/499
# K-Means iteration 369/499
# K-Means iteration 370/499
# K-Means iteration 371/499
# K-Means iteration 372/499
# K-Means iteration 373/499
# K-Means iteration 374/499
# K-Means iteration 375/499
# K-Means iteration 376/499
# K-Means iteration 377/499
# K-Means iteration 378/499
# K-Means iteration 379/499
# K-Means iteration 380/499
# K-Means iteration 381/499
# K-Means iteration 382/499
# K-Means iteration 383/499
# K-Means iteration 384/499
# K-Means iteration 385/499
# K-Means iteration 386/499
# K-Means iteration 387/499
# K-Means iteration 388/499
# K-Means iteration 389/499
# K-Means iteration 390/499
# K-Means iteration 391/499
# K-Means iteration 392/499
# K-Means iteration 393/499
# K-Means iteration 394/499
# K-Means iteration 395/499
# K-Means iteration 396/499
# K-Means iteration 397/499
# K-Means iteration 398/499
# K-Means iteration 399/499
# K-Means iteration 400/499
# K-Means iteration 401/499
# K-Means iteration 402/499
# K-Means iteration 403/499
# K-Means iteration 404/499
# K-Means iteration 405/499
# K-Means iteration 406/499
# K-Means iteration 407/499
# K-Means iteration 408/499
# K-Means iteration 409/499
# K-Means iteration 410/499
# K-Means iteration 411/499
# K-Means iteration 412/499
# K-Means iteration 413/499
# K-Means iteration 414/499
# K-Means iteration 415/499
# K-Means iteration 416/499
# K-Means iteration 417/499
# K-Means iteration 418/499
# K-Means iteration 419/499
# K-Means iteration 420/499
# K-Means iteration 421/499
# K-Means iteration 422/499
# K-Means iteration 423/499
# K-Means iteration 424/499
# K-Means iteration 425/499
# K-Means iteration 426/499
# K-Means iteration 427/499
# K-Means iteration 428/499
# K-Means iteration 429/499
# K-Means iteration 430/499
# K-Means iteration 431/499
# K-Means iteration 432/499
# K-Means iteration 433/499
# K-Means iteration 434/499
# K-Means iteration 435/499
# K-Means iteration 436/499
# K-Means iteration 437/499
# K-Means iteration 438/499
# K-Means iteration 439/499
# K-Means iteration 440/499
# K-Means iteration 441/499
# K-Means iteration 442/499
# K-Means iteration 443/499
# K-Means iteration 444/499
# K-Means iteration 445/499
# K-Means iteration 446/499
# K-Means iteration 447/499
# K-Means iteration 448/499
# K-Means iteration 449/499
# K-Means iteration 450/499
# K-Means iteration 451/499
# K-Means iteration 452/499
# K-Means iteration 453/499
# K-Means iteration 454/499
# K-Means iteration 455/499
# K-Means iteration 456/499
# K-Means iteration 457/499
# K-Means iteration 458/499
# K-Means iteration 459/499
# K-Means iteration 460/499
# K-Means iteration 461/499
# K-Means iteration 462/499
# K-Means iteration 463/499
# K-Means iteration 464/499
# K-Means iteration 465/499
# K-Means iteration 466/499
# K-Means iteration 467/499
# K-Means iteration 468/499
# K-Means iteration 469/499
# K-Means iteration 470/499
# K-Means iteration 471/499
# K-Means iteration 472/499
# K-Means iteration 473/499
# K-Means iteration 474/499
# K-Means iteration 475/499
# K-Means iteration 476/499
# K-Means iteration 477/499
# K-Means iteration 478/499
# K-Means iteration 479/499
# K-Means iteration 480/499
# K-Means iteration 481/499
# K-Means iteration 482/499
# K-Means iteration 483/499
# K-Means iteration 484/499
# K-Means iteration 485/499
# K-Means iteration 486/499
# K-Means iteration 487/499
# K-Means iteration 488/499
# K-Means iteration 489/499
# K-Means iteration 490/499
# K-Means iteration 491/499
# K-Means iteration 492/499
# K-Means iteration 493/499
# K-Means iteration 494/499
# K-Means iteration 495/499
# K-Means iteration 496/499
# K-Means iteration 497/499
# K-Means iteration 498/499
# K-Means iteration 499/499
# array([[3.04367119, 1.01541041],
#        [1.95399466, 5.02557006],
#        [6.03366736, 3.00052511]])

# %%
array([[1.95399466, 5.02557006],
       [3.04367119, 1.01541041],
       [6.03366736, 3.00052511]])

# %%
K = 3
max_iters =500
initial_centroids = kMeans_init_centroids(X, K)
centroids, idx = run_kMeans(X, initial_centroids, max_iters)
centroids
# Out:
# K-Means iteration 0/499
# K-Means iteration 1/499
# K-Means iteration 2/499
# K-Means iteration 3/499
# K-Means iteration 4/499
# K-Means iteration 5/499
# K-Means iteration 6/499
# K-Means iteration 7/499
# K-Means iteration 8/499
# K-Means iteration 9/499
# K-Means iteration 10/499
# K-Means iteration 11/499
# K-Means iteration 12/499
# K-Means iteration 13/499
# K-Means iteration 14/499
# K-Means iteration 15/499
# K-Means iteration 16/499
# K-Means iteration 17/499
# K-Means iteration 18/499
# K-Means iteration 19/499
# K-Means iteration 20/499
# K-Means iteration 21/499
# K-Means iteration 22/499
# K-Means iteration 23/499
# K-Means iteration 24/499
# K-Means iteration 25/499
# K-Means iteration 26/499
# K-Means iteration 27/499
# K-Means iteration 28/499
# K-Means iteration 29/499
# K-Means iteration 30/499
# K-Means iteration 31/499
# K-Means iteration 32/499
# K-Means iteration 33/499
# K-Means iteration 34/499
# K-Means iteration 35/499
# K-Means iteration 36/499
# K-Means iteration 37/499
# K-Means iteration 38/499
# K-Means iteration 39/499
# K-Means iteration 40/499
# K-Means iteration 41/499
# K-Means iteration 42/499
# K-Means iteration 43/499
# K-Means iteration 44/499
# K-Means iteration 45/499
# K-Means iteration 46/499
# K-Means iteration 47/499
# K-Means iteration 48/499
# K-Means iteration 49/499
# K-Means iteration 50/499
# K-Means iteration 51/499
# K-Means iteration 52/499
# K-Means iteration 53/499
# K-Means iteration 54/499
# K-Means iteration 55/499
# K-Means iteration 56/499
# K-Means iteration 57/499
# K-Means iteration 58/499
# K-Means iteration 59/499
# K-Means iteration 60/499
# K-Means iteration 61/499
# K-Means iteration 62/499
# K-Means iteration 63/499
# K-Means iteration 64/499
# K-Means iteration 65/499
# K-Means iteration 66/499
# K-Means iteration 67/499
# K-Means iteration 68/499
# K-Means iteration 69/499
# K-Means iteration 70/499
# K-Means iteration 71/499
# K-Means iteration 72/499
# K-Means iteration 73/499
# K-Means iteration 74/499
# K-Means iteration 75/499
# K-Means iteration 76/499
# K-Means iteration 77/499
# K-Means iteration 78/499
# K-Means iteration 79/499
# K-Means iteration 80/499
# K-Means iteration 81/499
# K-Means iteration 82/499
# K-Means iteration 83/499
# K-Means iteration 84/499
# K-Means iteration 85/499
# K-Means iteration 86/499
# K-Means iteration 87/499
# K-Means iteration 88/499
# K-Means iteration 89/499
# K-Means iteration 90/499
# K-Means iteration 91/499
# K-Means iteration 92/499
# K-Means iteration 93/499
# K-Means iteration 94/499
# K-Means iteration 95/499
# K-Means iteration 96/499
# K-Means iteration 97/499
# K-Means iteration 98/499
# K-Means iteration 99/499
# K-Means iteration 100/499
# K-Means iteration 101/499
# K-Means iteration 102/499
# K-Means iteration 103/499
# K-Means iteration 104/499
# K-Means iteration 105/499
# K-Means iteration 106/499
# K-Means iteration 107/499
# K-Means iteration 108/499
# K-Means iteration 109/499
# K-Means iteration 110/499
# K-Means iteration 111/499
# K-Means iteration 112/499
# K-Means iteration 113/499
# K-Means iteration 114/499
# K-Means iteration 115/499
# K-Means iteration 116/499
# K-Means iteration 117/499
# K-Means iteration 118/499
# K-Means iteration 119/499
# K-Means iteration 120/499
# K-Means iteration 121/499
# K-Means iteration 122/499
# K-Means iteration 123/499
# K-Means iteration 124/499
# K-Means iteration 125/499
# K-Means iteration 126/499
# K-Means iteration 127/499
# K-Means iteration 128/499
# K-Means iteration 129/499
# K-Means iteration 130/499
# K-Means iteration 131/499
# K-Means iteration 132/499
# K-Means iteration 133/499
# K-Means iteration 134/499
# K-Means iteration 135/499
# K-Means iteration 136/499
# K-Means iteration 137/499
# K-Means iteration 138/499
# K-Means iteration 139/499
# K-Means iteration 140/499
# K-Means iteration 141/499
# K-Means iteration 142/499
# K-Means iteration 143/499
# K-Means iteration 144/499
# K-Means iteration 145/499
# K-Means iteration 146/499
# K-Means iteration 147/499
# K-Means iteration 148/499
# K-Means iteration 149/499
# K-Means iteration 150/499
# K-Means iteration 151/499
# K-Means iteration 152/499
# K-Means iteration 153/499
# K-Means iteration 154/499
# K-Means iteration 155/499
# K-Means iteration 156/499
# K-Means iteration 157/499
# K-Means iteration 158/499
# K-Means iteration 159/499
# K-Means iteration 160/499
# K-Means iteration 161/499
# K-Means iteration 162/499
# K-Means iteration 163/499
# K-Means iteration 164/499
# K-Means iteration 165/499
# K-Means iteration 166/499
# K-Means iteration 167/499
# K-Means iteration 168/499
# K-Means iteration 169/499
# K-Means iteration 170/499
# K-Means iteration 171/499
# K-Means iteration 172/499
# K-Means iteration 173/499
# K-Means iteration 174/499
# K-Means iteration 175/499
# K-Means iteration 176/499
# K-Means iteration 177/499
# K-Means iteration 178/499
# K-Means iteration 179/499
# K-Means iteration 180/499
# K-Means iteration 181/499
# K-Means iteration 182/499
# K-Means iteration 183/499
# K-Means iteration 184/499
# K-Means iteration 185/499
# K-Means iteration 186/499
# K-Means iteration 187/499
# K-Means iteration 188/499
# K-Means iteration 189/499
# K-Means iteration 190/499
# K-Means iteration 191/499
# K-Means iteration 192/499
# K-Means iteration 193/499
# K-Means iteration 194/499
# K-Means iteration 195/499
# K-Means iteration 196/499
# K-Means iteration 197/499
# K-Means iteration 198/499
# K-Means iteration 199/499
# K-Means iteration 200/499
# K-Means iteration 201/499
# K-Means iteration 202/499
# K-Means iteration 203/499
# K-Means iteration 204/499
# K-Means iteration 205/499
# K-Means iteration 206/499
# K-Means iteration 207/499
# K-Means iteration 208/499
# K-Means iteration 209/499
# K-Means iteration 210/499
# K-Means iteration 211/499
# K-Means iteration 212/499
# K-Means iteration 213/499
# K-Means iteration 214/499
# K-Means iteration 215/499
# K-Means iteration 216/499
# K-Means iteration 217/499
# K-Means iteration 218/499
# K-Means iteration 219/499
# K-Means iteration 220/499
# K-Means iteration 221/499
# K-Means iteration 222/499
# K-Means iteration 223/499
# K-Means iteration 224/499
# K-Means iteration 225/499
# K-Means iteration 226/499
# K-Means iteration 227/499
# K-Means iteration 228/499
# K-Means iteration 229/499
# K-Means iteration 230/499
# K-Means iteration 231/499
# K-Means iteration 232/499
# K-Means iteration 233/499
# K-Means iteration 234/499
# K-Means iteration 235/499
# K-Means iteration 236/499
# K-Means iteration 237/499
# K-Means iteration 238/499
# K-Means iteration 239/499
# K-Means iteration 240/499
# K-Means iteration 241/499
# K-Means iteration 242/499
# K-Means iteration 243/499
# K-Means iteration 244/499
# K-Means iteration 245/499
# K-Means iteration 246/499
# K-Means iteration 247/499
# K-Means iteration 248/499
# K-Means iteration 249/499
# K-Means iteration 250/499
# K-Means iteration 251/499
# K-Means iteration 252/499
# K-Means iteration 253/499
# K-Means iteration 254/499
# K-Means iteration 255/499
# K-Means iteration 256/499
# K-Means iteration 257/499
# K-Means iteration 258/499
# K-Means iteration 259/499
# K-Means iteration 260/499
# K-Means iteration 261/499
# K-Means iteration 262/499
# K-Means iteration 263/499
# K-Means iteration 264/499
# K-Means iteration 265/499
# K-Means iteration 266/499
# K-Means iteration 267/499
# K-Means iteration 268/499
# K-Means iteration 269/499
# K-Means iteration 270/499
# K-Means iteration 271/499
# K-Means iteration 272/499
# K-Means iteration 273/499
# K-Means iteration 274/499
# K-Means iteration 275/499
# K-Means iteration 276/499
# K-Means iteration 277/499
# K-Means iteration 278/499
# K-Means iteration 279/499
# K-Means iteration 280/499
# K-Means iteration 281/499
# K-Means iteration 282/499
# K-Means iteration 283/499
# K-Means iteration 284/499
# K-Means iteration 285/499
# K-Means iteration 286/499
# K-Means iteration 287/499
# K-Means iteration 288/499
# K-Means iteration 289/499
# K-Means iteration 290/499
# K-Means iteration 291/499
# K-Means iteration 292/499
# K-Means iteration 293/499
# K-Means iteration 294/499
# K-Means iteration 295/499
# K-Means iteration 296/499
# K-Means iteration 297/499
# K-Means iteration 298/499
# K-Means iteration 299/499
# K-Means iteration 300/499
# K-Means iteration 301/499
# K-Means iteration 302/499
# K-Means iteration 303/499
# K-Means iteration 304/499
# K-Means iteration 305/499
# K-Means iteration 306/499
# K-Means iteration 307/499
# K-Means iteration 308/499
# K-Means iteration 309/499
# K-Means iteration 310/499
# K-Means iteration 311/499
# K-Means iteration 312/499
# K-Means iteration 313/499
# K-Means iteration 314/499
# K-Means iteration 315/499
# K-Means iteration 316/499
# K-Means iteration 317/499
# K-Means iteration 318/499
# K-Means iteration 319/499
# K-Means iteration 320/499
# K-Means iteration 321/499
# K-Means iteration 322/499
# K-Means iteration 323/499
# K-Means iteration 324/499
# K-Means iteration 325/499
# K-Means iteration 326/499
# K-Means iteration 327/499
# K-Means iteration 328/499
# K-Means iteration 329/499
# K-Means iteration 330/499
# K-Means iteration 331/499
# K-Means iteration 332/499
# K-Means iteration 333/499
# K-Means iteration 334/499
# K-Means iteration 335/499
# K-Means iteration 336/499
# K-Means iteration 337/499
# K-Means iteration 338/499
# K-Means iteration 339/499
# K-Means iteration 340/499
# K-Means iteration 341/499
# K-Means iteration 342/499
# K-Means iteration 343/499
# K-Means iteration 344/499
# K-Means iteration 345/499
# K-Means iteration 346/499
# K-Means iteration 347/499
# K-Means iteration 348/499
# K-Means iteration 349/499
# K-Means iteration 350/499
# K-Means iteration 351/499
# K-Means iteration 352/499
# K-Means iteration 353/499
# K-Means iteration 354/499
# K-Means iteration 355/499
# K-Means iteration 356/499
# K-Means iteration 357/499
# K-Means iteration 358/499
# K-Means iteration 359/499
# K-Means iteration 360/499
# K-Means iteration 361/499
# K-Means iteration 362/499
# K-Means iteration 363/499
# K-Means iteration 364/499
# K-Means iteration 365/499
# K-Means iteration 366/499
# K-Means iteration 367/499
# K-Means iteration 368/499
# K-Means iteration 369/499
# K-Means iteration 370/499
# K-Means iteration 371/499
# K-Means iteration 372/499
# K-Means iteration 373/499
# K-Means iteration 374/499
# K-Means iteration 375/499
# K-Means iteration 376/499
# K-Means iteration 377/499
# K-Means iteration 378/499
# K-Means iteration 379/499
# K-Means iteration 380/499
# K-Means iteration 381/499
# K-Means iteration 382/499
# K-Means iteration 383/499
# K-Means iteration 384/499
# K-Means iteration 385/499
# K-Means iteration 386/499
# K-Means iteration 387/499
# K-Means iteration 388/499
# K-Means iteration 389/499
# K-Means iteration 390/499
# K-Means iteration 391/499
# K-Means iteration 392/499
# K-Means iteration 393/499
# K-Means iteration 394/499
# K-Means iteration 395/499
# K-Means iteration 396/499
# K-Means iteration 397/499
# K-Means iteration 398/499
# K-Means iteration 399/499
# K-Means iteration 400/499
# K-Means iteration 401/499
# K-Means iteration 402/499
# K-Means iteration 403/499
# K-Means iteration 404/499
# K-Means iteration 405/499
# K-Means iteration 406/499
# K-Means iteration 407/499
# K-Means iteration 408/499
# K-Means iteration 409/499
# K-Means iteration 410/499
# K-Means iteration 411/499
# K-Means iteration 412/499
# K-Means iteration 413/499
# K-Means iteration 414/499
# K-Means iteration 415/499
# K-Means iteration 416/499
# K-Means iteration 417/499
# K-Means iteration 418/499
# K-Means iteration 419/499
# K-Means iteration 420/499
# K-Means iteration 421/499
# K-Means iteration 422/499
# K-Means iteration 423/499
# K-Means iteration 424/499
# K-Means iteration 425/499
# K-Means iteration 426/499
# K-Means iteration 427/499
# K-Means iteration 428/499
# K-Means iteration 429/499
# K-Means iteration 430/499
# K-Means iteration 431/499
# K-Means iteration 432/499
# K-Means iteration 433/499
# K-Means iteration 434/499
# K-Means iteration 435/499
# K-Means iteration 436/499
# K-Means iteration 437/499
# K-Means iteration 438/499
# K-Means iteration 439/499
# K-Means iteration 440/499
# K-Means iteration 441/499
# K-Means iteration 442/499
# K-Means iteration 443/499
# K-Means iteration 444/499
# K-Means iteration 445/499
# K-Means iteration 446/499
# K-Means iteration 447/499
# K-Means iteration 448/499
# K-Means iteration 449/499
# K-Means iteration 450/499
# K-Means iteration 451/499
# K-Means iteration 452/499
# K-Means iteration 453/499
# K-Means iteration 454/499
# K-Means iteration 455/499
# K-Means iteration 456/499
# K-Means iteration 457/499
# K-Means iteration 458/499
# K-Means iteration 459/499
# K-Means iteration 460/499
# K-Means iteration 461/499
# K-Means iteration 462/499
# K-Means iteration 463/499
# K-Means iteration 464/499
# K-Means iteration 465/499
# K-Means iteration 466/499
# K-Means iteration 467/499
# K-Means iteration 468/499
# K-Means iteration 469/499
# K-Means iteration 470/499
# K-Means iteration 471/499
# K-Means iteration 472/499
# K-Means iteration 473/499
# K-Means iteration 474/499
# K-Means iteration 475/499
# K-Means iteration 476/499
# K-Means iteration 477/499
# K-Means iteration 478/499
# K-Means iteration 479/499
# K-Means iteration 480/499
# K-Means iteration 481/499
# K-Means iteration 482/499
# K-Means iteration 483/499
# K-Means iteration 484/499
# K-Means iteration 485/499
# K-Means iteration 486/499
# K-Means iteration 487/499
# K-Means iteration 488/499
# K-Means iteration 489/499
# K-Means iteration 490/499
# K-Means iteration 491/499
# K-Means iteration 492/499
# K-Means iteration 493/499
# K-Means iteration 494/499
# K-Means iteration 495/499
# K-Means iteration 496/499
# K-Means iteration 497/499
# K-Means iteration 498/499
# K-Means iteration 499/499
# array([[3.04367119, 1.01541041],
#        [6.03366736, 3.00052511],
#        [1.95399466, 5.02557006]])

# %%
array([[3.04367119, 1.01541041],
       [1.95399466, 5.02557006],
       [6.03366736, 3.00052511]])
